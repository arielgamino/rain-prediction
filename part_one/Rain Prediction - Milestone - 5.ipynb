# %% [markdown]
# #### Objective
# * Developing a Logistic Regression model to predict whether or not it will rain tomorrow.

# %%
import pandas as pd
pd.set_option('display.max_rows', 150)

from sklearn.linear_model import LogisticRegression
from joblib import dump, load
from sklearn.metrics import accuracy_score

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# %%javascript
# //Disable autoscrolling to see entire graph
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ##### 1. Develop a Logistic Regression model with an arbitrary random_state.
# * You can also set the underlying optimization library by setting the solver parameter.features and labels into training and testing set with 20% test size.

# %%
# Read training, test, labels
X_train = pd.read_pickle("X_train.pkl")
X_test  = pd.read_pickle("X_test.pkl")
y_train = pd.read_pickle("y_train.pkl")
y_test  = pd.read_pickle("y_test.pkl")

# %% [markdown]
# ##### 2. Train the model with the prepared training features and labels.

# %%
log_regression = LogisticRegression(solver='liblinear', random_state=0)

# %%
log_regression.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %% [markdown]
# ##### 3 Predict the next day's rain forecast for the prepared testing data.
# * Calculate the probabilities for negative and positive classes.

# %%
y_prediction_test = log_regression.predict(X_test)

# %%
y_prediction_test
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int8)

# %%
# Probability of No rain (0)
log_regression.predict_proba(X_test)[:,0]
# Out:
# array([0.92399234, 0.87930385, 0.86377416, ..., 0.98321557, 0.83075673,
#        0.39542325])

# %%
# Probability of Yes rain (1)
log_regression.predict_proba(X_test)[:,1]
# Out:
# array([0.07600766, 0.12069615, 0.13622584, ..., 0.01678443, 0.16924327,
#        0.60457675])

# %% [markdown]
# ##### 4. Calculate the accuracy score of the model for the predicted results.

# %%
test_accuracy_score  = accuracy_score(y_test, y_prediction_test)

# %%
print(f"Accuracy Score is:{test_accuracy_score*100:.2f}%")
# Out:
# Accuracy Score is:84.80%

# %% [markdown]
# ##### 5. Interpret the model results by checking feature importance:
# * Check the learned weights for each feature.
# * Check the bias term.

# %%
# Learned weights for each feature
model_weights = log_regression.coef_[0]
# Bias (Incercept)
model_bias = log_regression.intercept_[0]

# %%
# Create a dataframe with feature and weights for easier displaying
column_names = X_train.columns
data = {'Feature':column_names, 'Weights':model_weights}
df = pd.DataFrame(data=data)

# %%
df.head(117)
# Out:
#                        Feature    Weights
# 0                      MinTemp   0.933536
# 1                      MaxTemp  -2.836491
# 2                     Rainfall   1.499092
# 3                  Evaporation   0.185941
# 4                     Sunshine  -1.532401
# 5                WindGustSpeed   4.117873
# 6                 WindSpeed9am  -0.251537
# 7                 WindSpeed3pm  -0.880591
# 8                  Humidity9am   0.538222
# 9                  Humidity3pm   5.782802
# 10                 Pressure9am   6.291682
# 11                 Pressure3pm -10.066159
# 12                    Cloud9am   0.052091
# 13                    Cloud3pm   1.022614
# 14                     Temp9am   1.090419
# 15                     Temp3pm   1.479544
# 16                   RainToday   0.417082
# 17                       month   0.132771
# 18                        year   0.172853
# 19                         day  -0.043783
# 20               WindGustDir_E  -0.300330
# 21             WindGustDir_ENE  -0.287360
# 22             WindGustDir_ESE  -0.174088
# 23               WindGustDir_N  -0.245046
# 24              WindGustDir_NE  -0.370986
# 25             WindGustDir_NNE  -0.400343
# 26             WindGustDir_NNW  -0.167223
# 27              WindGustDir_NW  -0.181912
# 28               WindGustDir_S  -0.157855
# 29              WindGustDir_SE  -0.225324
# 30             WindGustDir_SSE  -0.178027
# 31             WindGustDir_SSW  -0.251478
# 32              WindGustDir_SW  -0.224839
# 33               WindGustDir_W  -0.200432
# 34             WindGustDir_WNW  -0.259927
# 35             WindGustDir_WSW  -0.251455
# 36                WindDir9am_E  -0.387119
# 37              WindDir9am_ENE  -0.119543
# 38              WindDir9am_ESE  -0.415506
# 39                WindDir9am_N  -0.159792
# 40               WindDir9am_NE  -0.093879
# 41              WindDir9am_NNE   0.041911
# 42              WindDir9am_NNW  -0.204816
# 43               WindDir9am_NW  -0.198882
# 44                WindDir9am_S  -0.468779
# 45               WindDir9am_SE  -0.438721
# 46              WindDir9am_SSE  -0.483416
# 47              WindDir9am_SSW  -0.291803
# 48               WindDir9am_SW  -0.152755
# 49                WindDir9am_W  -0.189962
# 50              WindDir9am_WNW  -0.181985
# 51              WindDir9am_WSW  -0.131578
# 52           Location_Adelaide   0.559263
# 53             Location_Albany  -0.141351
# 54             Location_Albury   0.427986
# 55       Location_AliceSprings  -0.147554
# 56      Location_BadgerysCreek   0.180172
# 57           Location_Ballarat  -0.366226
# 58            Location_Bendigo   0.125600
# 59           Location_Brisbane   0.318350
# 60             Location_Cairns  -0.139705
# 61           Location_Canberra   0.083591
# 62              Location_Cobar   0.275173
# 63       Location_CoffsHarbour  -0.062386
# 64           Location_Dartmoor  -0.011786
# 65             Location_Darwin  -0.609364
# 66          Location_GoldCoast  -0.319615
# 67             Location_Hobart  -0.622310
# 68          Location_Katherine  -0.481397
# 69         Location_Launceston  -0.292900
# 70          Location_Melbourne  -0.143151
# 71   Location_MelbourneAirport  -0.614660
# 72            Location_Mildura  -0.056103
# 73              Location_Moree   0.035132
# 74       Location_MountGambier  -0.056055
# 75        Location_MountGinini  -1.006603
# 76          Location_Newcastle  -0.124094
# 77               Location_Nhil  -0.109221
# 78          Location_NorahHead  -0.557677
# 79      Location_NorfolkIsland  -0.579934
# 80          Location_Nuriootpa  -0.131018
# 81         Location_PearceRAAF   0.327063
# 82            Location_Penrith   0.459688
# 83              Location_Perth   0.542216
# 84       Location_PerthAirport   0.322216
# 85           Location_Portland  -0.067623
# 86           Location_Richmond   0.151619
# 87               Location_Sale  -0.404220
# 88         Location_SalmonGums   0.396086
# 89             Location_Sydney  -0.055749
# 90      Location_SydneyAirport  -0.244378
# 91         Location_Townsville  -0.778590
# 92        Location_Tuggeranong   0.296650
# 93              Location_Uluru   0.127362
# 94         Location_WaggaWagga   0.191396
# 95            Location_Walpole   0.122225
# 96           Location_Watsonia  -0.329338
# 97        Location_Williamtown   0.228241
# 98        Location_Witchcliffe   0.605126
# 99         Location_Wollongong  -0.879085
# 100           Location_Woomera  -0.319690
# 101               WindDir3pm_E  -0.320884
# 102             WindDir3pm_ENE  -0.229392
# 103             WindDir3pm_ESE  -0.323188
# 104               WindDir3pm_N  -0.038079
# 105              WindDir3pm_NE  -0.401596
# 106             WindDir3pm_NNE  -0.162606
# 107             WindDir3pm_NNW   0.103325
# 108              WindDir3pm_NW   0.071237
# 109               WindDir3pm_S  -0.322765
# 110              WindDir3pm_SE  -0.161950
# 111             WindDir3pm_SSE  -0.443446
# 112             WindDir3pm_SSW  -0.374737
# 113              WindDir3pm_SW  -0.481556
# 114               WindDir3pm_W  -0.290988
# 115             WindDir3pm_WNW  -0.127546
# 116             WindDir3pm_WSW  -0.372455

# %%
# print bias
print(f"The bias (intercept) for this model is:{model_bias}")
# Out:
# The bias (intercept) for this model is:-3.8766255101624965

# %%
# From Project 3 - Milestone 1, save sklearn model
dump(log_regression,'log_regression_project_1.joblib')
# Out:
# ['log_regression_project_1.joblib']
