# %% [markdown]
# #### Objective
# * Developing a Logistic Regression model to predict whether or not it will rain tomorrow.

# %%
import pandas as pd
pd.set_option('display.max_rows', 150)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# %%javascript
# //Disable autoscrolling to see entire graph
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ##### 1. Develop a Logistic Regression model with an arbitrary random_state.
# * You can also set the underlying optimization library by setting the solver parameter.features and labels into training and testing set with 20% test size.

# %%
# Read training, test, labels
X_train = pd.read_pickle("X_train.pkl")
X_test  = pd.read_pickle("X_test.pkl")
y_train = pd.read_pickle("y_train.pkl")
y_test  = pd.read_pickle("y_test.pkl")

# %% [markdown]
# ##### 2. Train the model with the prepared training features and labels.

# %%
log_regression = LogisticRegression(solver='liblinear', random_state=0)

# %%
log_regression.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %% [markdown]
# ##### 3 Predict the next day's rain forecast for the prepared testing data.
# * Calculate the probabilities for negative and positive classes.

# %%
y_prediction_test = log_regression.predict(X_test)

# %%
y_prediction_test
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int8)

# %%
# Probability of No rain (0)
log_regression.predict_proba(X_test)[:,0]
# Out:
# array([0.92399157, 0.87930321, 0.86377542, ..., 0.98321543, 0.830756  ,
#        0.39542593])

# %%
# Probability of Yes rain (1)
log_regression.predict_proba(X_test)[:,1]
# Out:
# array([0.07600843, 0.12069679, 0.13622458, ..., 0.01678457, 0.169244  ,
#        0.60457407])

# %% [markdown]
# ##### 4. Calculate the accuracy score of the model for the predicted results.

# %%
test_accuracy_score  = accuracy_score(y_test, y_prediction_test)

# %%
print(f"Accuracy Score is:{test_accuracy_score*100:.2f}%")
# Out:
# Accuracy Score is:84.80%

# %% [markdown]
# ##### 5. Interpret the model results by checking feature importance:
# * Check the learned weights for each feature.
# * Check the bias term.

# %%
# Learned weights for each feature
model_weights = log_regression.coef_[0]
# Bias (Incercept)
model_bias = log_regression.intercept_[0]

# %%
# Create a dataframe with feature and weights for easier displaying
column_names = X_train.columns
data = {'Feature':column_names, 'Weights':model_weights}
df = pd.DataFrame(data=data)

# %%
df.head(117)
# Out:
#                        Feature    Weights
# 0                      MinTemp   0.933522
# 1                      MaxTemp  -2.836488
# 2                     Rainfall   1.499090
# 3                  Evaporation   0.185940
# 4                     Sunshine  -1.532400
# 5                WindGustSpeed   4.117874
# 6                 WindSpeed9am  -0.251538
# 7                 WindSpeed3pm  -0.880593
# 8                  Humidity9am   0.538224
# 9                  Humidity3pm   5.782802
# 10                 Pressure9am   6.291656
# 11                 Pressure3pm -10.066131
# 12                    Cloud9am   0.052089
# 13                    Cloud3pm   1.022610
# 14                     Temp9am   1.090437
# 15                     Temp3pm   1.479542
# 16                   RainToday   0.417072
# 17                       month   0.132772
# 18                        year   0.172854
# 19                         day  -0.043780
# 20           Location_Adelaide   0.559264
# 21             Location_Albany  -0.141352
# 22             Location_Albury   0.427986
# 23       Location_AliceSprings  -0.147553
# 24      Location_BadgerysCreek   0.180172
# 25           Location_Ballarat  -0.366226
# 26            Location_Bendigo   0.125600
# 27           Location_Brisbane   0.318351
# 28             Location_Cairns  -0.139705
# 29           Location_Canberra   0.083591
# 30              Location_Cobar   0.275173
# 31       Location_CoffsHarbour  -0.062386
# 32           Location_Dartmoor  -0.011786
# 33             Location_Darwin  -0.609364
# 34          Location_GoldCoast  -0.319615
# 35             Location_Hobart  -0.622311
# 36          Location_Katherine  -0.481397
# 37         Location_Launceston  -0.292901
# 38          Location_Melbourne  -0.143150
# 39   Location_MelbourneAirport  -0.614660
# 40            Location_Mildura  -0.056103
# 41              Location_Moree   0.035133
# 42       Location_MountGambier  -0.056055
# 43        Location_MountGinini  -1.006605
# 44          Location_Newcastle  -0.124095
# 45               Location_Nhil  -0.109222
# 46          Location_NorahHead  -0.557676
# 47      Location_NorfolkIsland  -0.579934
# 48          Location_Nuriootpa  -0.131019
# 49         Location_PearceRAAF   0.327064
# 50            Location_Penrith   0.459688
# 51              Location_Perth   0.542216
# 52       Location_PerthAirport   0.322217
# 53           Location_Portland  -0.067624
# 54           Location_Richmond   0.151620
# 55               Location_Sale  -0.404220
# 56         Location_SalmonGums   0.396086
# 57             Location_Sydney  -0.055749
# 58      Location_SydneyAirport  -0.244377
# 59         Location_Townsville  -0.778591
# 60        Location_Tuggeranong   0.296650
# 61              Location_Uluru   0.127365
# 62         Location_WaggaWagga   0.191394
# 63            Location_Walpole   0.122224
# 64           Location_Watsonia  -0.329339
# 65        Location_Williamtown   0.228242
# 66        Location_Witchcliffe   0.605125
# 67         Location_Wollongong  -0.879084
# 68            Location_Woomera  -0.319689
# 69                WindDir3pm_E  -0.320884
# 70              WindDir3pm_ENE  -0.229393
# 71              WindDir3pm_ESE  -0.323189
# 72                WindDir3pm_N  -0.038077
# 73               WindDir3pm_NE  -0.401595
# 74              WindDir3pm_NNE  -0.162605
# 75              WindDir3pm_NNW   0.103327
# 76               WindDir3pm_NW   0.071237
# 77                WindDir3pm_S  -0.322764
# 78               WindDir3pm_SE  -0.161951
# 79              WindDir3pm_SSE  -0.443446
# 80              WindDir3pm_SSW  -0.374736
# 81               WindDir3pm_SW  -0.481557
# 82                WindDir3pm_W  -0.290988
# 83              WindDir3pm_WNW  -0.127546
# 84              WindDir3pm_WSW  -0.372458
# 85                WindDir9am_E  -0.387117
# 86              WindDir9am_ENE  -0.119542
# 87              WindDir9am_ESE  -0.415505
# 88                WindDir9am_N  -0.159791
# 89               WindDir9am_NE  -0.093878
# 90              WindDir9am_NNE   0.041911
# 91              WindDir9am_NNW  -0.204817
# 92               WindDir9am_NW  -0.198880
# 93                WindDir9am_S  -0.468779
# 94               WindDir9am_SE  -0.438720
# 95              WindDir9am_SSE  -0.483416
# 96              WindDir9am_SSW  -0.291802
# 97               WindDir9am_SW  -0.152755
# 98                WindDir9am_W  -0.189965
# 99              WindDir9am_WNW  -0.181987
# 100             WindDir9am_WSW  -0.131580
# 101              WindGustDir_E  -0.300331
# 102            WindGustDir_ENE  -0.287359
# 103            WindGustDir_ESE  -0.174089
# 104              WindGustDir_N  -0.245044
# 105             WindGustDir_NE  -0.370984
# 106            WindGustDir_NNE  -0.400342
# 107            WindGustDir_NNW  -0.167221
# 108             WindGustDir_NW  -0.181912
# 109              WindGustDir_S  -0.157855
# 110             WindGustDir_SE  -0.225324
# 111            WindGustDir_SSE  -0.178029
# 112            WindGustDir_SSW  -0.251477
# 113             WindGustDir_SW  -0.224842
# 114              WindGustDir_W  -0.200431
# 115            WindGustDir_WNW  -0.259926
# 116            WindGustDir_WSW  -0.251459

# %%
# print bias
print(f"The bias (intercept) for this model is:{model_bias}")
# Out:
# The bias (intercept) for this model is:-3.8766254482389724
